# %% [markdown]
# Import Data

# %%
# !pip install pandas
import pandas as pd

# %%
carbon_price_url = 'https://raw.githubusercontent.com/Erica-zya/Honor-Thesis/main/Data/Daily%20Carbon%20Price_EU.csv'
carbon_price = pd.read_csv(carbon_price_url, header=0)
carbon_price['Date'] = pd.to_datetime(carbon_price['Date'])

oil_price_url = 'https://raw.githubusercontent.com/Erica-zya/Honor-Thesis/main/Data/Daily%20Crude%20Oil%20Price_Brent%20Oil%20Futures.csv'
oil_price = pd.read_csv(oil_price_url, header=0)
oil_price['Date'] = pd.to_datetime(oil_price['Date'])

coal_price_url = 'https://raw.githubusercontent.com/Erica-zya/Honor-Thesis/main/Data/Daily%20Coal%20Price_Rotterdam%20Coal.csv'
coal_price = pd.read_csv(coal_price_url, header=0)
coal_price['Date'] = pd.to_datetime(coal_price['Date'])

gas_price_url = 'https://raw.githubusercontent.com/Erica-zya/Honor-Thesis/main/Data/Daily%20Natural%20Gas%20Price_Dutch%20TTF.csv'
gas_price = pd.read_csv(gas_price_url, header=0)
gas_price['Date'] = pd.to_datetime(gas_price['Date'])

# %% [markdown]
# # Carbon Price

# %% [markdown]
# Find the mean, variance, standard deviation, minimum, maximum for carbon price.

# %%
carbon_mean = carbon_price['Price'].mean()
carbon_variance = carbon_price['Price'].var()
carbon_sd = carbon_price['Price'].std()
carbon_max = carbon_price['Price'].max()
carbon_min = carbon_price['Price'].min()

print("Mean:", carbon_mean)
print("Variance:", carbon_variance)
print("Standard Deviation:", carbon_sd)
print("Maximum:", carbon_max)
print("Minimum:", carbon_min)
# Out:
# Mean: 22.80935192780975
# Variance: 595.0119356209444
# Standard Deviation: 24.392866490450533
# Maximum: 98.01
# Minimum: 0.01

# %% [markdown]
# Plot the diagram

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.plot(carbon_price['Date'], carbon_price['Price'], marker='o', markersize=1, linestyle='-')
plt.title('Carbon Price Over Time')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Crude Oil Price

# %% [markdown]
# Find the mean, variance, standard deviation, minimum, maximum for crude oil price.

# %%
oil_mean = oil_price['Price'].mean()
oil_variance = oil_price['Price'].var()
oil_sd = oil_price['Price'].std()
oil_max = oil_price['Price'].max()
oil_min = oil_price['Price'].min()

print("Mean:", oil_mean)
print("Variance:", oil_variance)
print("Standard Deviation:", oil_sd)
print("Maximum:", oil_max)
print("Minimum:", oil_min)
# Out:
# Mean: 76.84139971139965
# Variance: 580.8552865146302
# Standard Deviation: 24.100939535931584
# Maximum: 146.08
# Minimum: 19.33

# %% [markdown]
# Plot the diagram

# %%
plt.figure(figsize=(10, 6))
plt.plot(oil_price['Date'], oil_price['Price'], marker='o', markersize=1, linestyle='-')
plt.title('Oil Price Over Time')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Coal Price

# %% [markdown]
# Find the mean, variance, standard deviation, minimum, maximum for crude oil price.

# %%
coal_mean = coal_price['Price'].mean()
coal_variance = coal_price['Price'].var()
coal_sd = coal_price['Price'].std()
coal_max = coal_price['Price'].max()
coal_min = coal_price['Price'].min()

print("Mean:", coal_mean)
print("Variance:", coal_variance)
print("Standard Deviation:", coal_sd)
print("Maximum:", coal_max)
print("Minimum:", coal_min)
# Out:
# Mean: 99.58807341490567
# Variance: 3482.277743149935
# Standard Deviation: 59.0108273382939
# Maximum: 439.0
# Minimum: 38.45

# %% [markdown]
# Plot the diagram

# %%
plt.figure(figsize=(10, 6))
plt.plot(coal_price['Date'], coal_price['Price'], marker='o', markersize=1, linestyle='-')
plt.title('Coal Price Over Time')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Natural Gas Price

# %%
Find the mean, variance, standard deviation, minimum, maximum for natural gas price.

# %%
gas_mean = gas_price['Price'].mean()
gas_variance = gas_price['Price'].var()
gas_sd = gas_price['Price'].std()
gas_max = gas_price['Price'].max()
gas_min = gas_price['Price'].min()

print("Mean:", gas_mean)
print("Variance:", gas_variance)
print("Standard Deviation:", gas_sd)
print("Maximum:", gas_max)
print("Minimum:", gas_min)
# Out:
# Mean: 43.74607788944725
# Variance: 2308.906997227115
# Standard Deviation: 48.051087367791325
# Maximum: 339.195
# Minimum: 3.51

# %% [markdown]
# Plot the diagram

# %%
plt.figure(figsize=(10, 6))
plt.plot(gas_price['Date'], gas_price['Price'], marker='o', markersize=1, linestyle='-')
plt.title('Natural Gas Price Over Time')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(True)
plt.tight_layout()
plt.show()
